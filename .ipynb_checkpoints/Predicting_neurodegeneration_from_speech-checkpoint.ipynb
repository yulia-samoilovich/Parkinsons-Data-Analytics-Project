# %% [markdown]
# # Hypothesis
# The duration of pauses in speech will be longer for Parkinson's Disorder (PD) and REM Behaviour Disorder (RBD) patients compared to the healthy controls (HC). This reflects difficulties in speech initiation and continuation.
#
# https://archive.ics.uci.edu/dataset/392/early+biomarkers+of+parkinson+s+disease+based+on+natural+connected+speech

# %%
import pandas as pd
import numpy as np

# %matplotlib inline

# %%
df_parkinsons = pd.read_csv('dataset.csv')

# %%
df_parkinsons.head()
# Out:
#          Unnamed: 0 Demographic information Demographic information.1  \
# 0  Participant code             Age (years)                    Gender
# 1              PD01                      58                         F
# 2              PD02                      68                         F
# 3              PD03                      68                         M
# 4              PD04                      75                         M
#
#                               Clinical information  \
# 0  Positive history of Parkinson disease in family
# 1                                               No
# 2                                               No
# 3                                               No
# 4                                               No
#
#          Clinical information.1  \
# 0  Age of disease onset (years)
# 1                            56
# 2                            67
# 3                            67
# 4                            73
#
#                             Clinical information.2              Medication  \
# 0  Duration of disease from first symptoms (years)  Antidepressant therapy
# 1                                                2                      No
# 2                                                1                      No
# 3                                                1                      No
# 4                                                2                      No
#
#                   Medication.1              Medication.2  \
# 0  Antiparkinsonian medication  Antipsychotic medication
# 1                           No                        No
# 2                           No                        No
# 3                           No                        No
# 4                           No                        No
#
#                 Medication.3  ...  \
# 0  Benzodiazepine medication  ...
# 1                         No  ...
# 2                         No  ...
# 3                         No  ...
# 4                         No  ...
#
#   Speech examination: speaking task of monologue.2  \
# 0           Acceleration of speech timing (-/min2)
# 1                                            -2.82
# 2                                              8.2
# 3                                             4.71
# 4                                            -9.09
#
#   Speech examination: speaking task of monologue.3  \
# 0                 Duration of pause intervals (ms)
# 1                                              158
# 2                                              295
# 3                                              280
# 4                                              397
#
#   Speech examination: speaking task of monologue.4  \
# 0                Duration of voiced intervals (ms)
# 1                                              318
# 2                                              264
# 3                                              317
# 4                                              800
#
#     Speech examination: speaking task of monologue.5  \
# 0  Gaping                         in-between voic...
# 1                                              49.01
# 2                                              40.56
# 3                                              48.97
# 4                                              18.69
#
#   Speech examination: speaking task of monologue.6  \
# 0                  Duration of unvoiced stops (ms)
# 1                                            22.37
# 2                                            26.88
# 3                                            22.37
# 4                                            49.37
#
#     Speech examination: speaking task of monologue.7  \
# 0  Decay of unvoiced fricatives              (?/min)
# 1                                              0.588
# 2                                             -0.825
# 3                                             -0.955
# 4                                              0.791
#
#   Speech examination: speaking task of monologue.8  \
# 0            Relative loudness of respiration (dB)
# 1                                           -19.77
# 2                                           -23.26
# 3                                           -13.29
# 4                                           -25.08
#
#   Speech examination: speaking task of monologue.9  \
# 0              Pause intervals per respiration (-)
# 1                                                6
# 2                                                4
# 3                                                4
# 4                                                2
#
#   Speech examination: speaking task of monologue.10  \
# 0     Rate of speech respiration           (- /min)
# 1                                             13.81
# 2                                             21.77
# 3                                             22.52
# 4                                             14.37
#
#   Speech examination: speaking task of monologue.11
# 0             Latency of\nrespiratory exchange (ms)
# 1                                               127
# 2                                               313
# 3                                               201
# 4                                               151
#
# [5 rows x 65 columns]

# %%
df_parkinsons.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 131 entries, 0 to 130
# Data columns (total 65 columns):
#  #   Column                                                   Non-Null Count  Dtype
# ---  ------                                                   --------------  -----
#  0   Unnamed: 0                                               131 non-null    object
#  1   Demographic information                                  131 non-null    object
#  2   Demographic information.1                                131 non-null    object
#  3   Clinical information                                     131 non-null    object
#  4   Clinical information.1                                   131 non-null    object
#  5   Clinical information.2                                   131 non-null    object
#  6   Medication                                               131 non-null    object
#  7   Medication.1                                             131 non-null    object
#  8   Medication.2                                             131 non-null    object
#  9   Medication.3                                             131 non-null    object
#  10  Medication.4                                             131 non-null    object
#  11  Medication.5                                             131 non-null    object
#  12  Overview of motor examination                            131 non-null    object
#  13  Overview of motor examination.1                          131 non-null    object
#  14  UPDRS III motor scale: specific items                    131 non-null    object
#  15  UPDRS III motor scale: specific items.1                  131 non-null    object
#  16  UPDRS III motor scale: specific items.2                  131 non-null    object
#  17  UPDRS III motor scale: specific items.3                  131 non-null    object
#  18  UPDRS III motor scale: specific items.4                  131 non-null    object
#  19  UPDRS III motor scale: specific items.5                  131 non-null    object
#  20  UPDRS III motor scale: specific items.6                  131 non-null    object
#  21  UPDRS III motor scale: specific items.7                  131 non-null    object
#  22  UPDRS III motor scale: specific items.8                  131 non-null    object
#  23  UPDRS III motor scale: specific items.9                  131 non-null    object
#  24  UPDRS III motor scale: specific items.10                 131 non-null    object
#  25  UPDRS III motor scale: specific items.11                 131 non-null    object
#  26  UPDRS III motor scale: specific items.12                 131 non-null    object
#  27  UPDRS III motor scale: specific items.13                 131 non-null    object
#  28  UPDRS III motor scale: specific items.14                 131 non-null    object
#  29  UPDRS III motor scale: specific items.15                 131 non-null    object
#  30  UPDRS III motor scale: specific items.16                 131 non-null    object
#  31  UPDRS III motor scale: specific items.17                 131 non-null    object
#  32  UPDRS III motor scale: specific items.18                 131 non-null    object
#  33  UPDRS III motor scale: specific items.19                 131 non-null    object
#  34  UPDRS III motor scale: specific items.20                 131 non-null    object
#  35  UPDRS III motor scale: specific items.21                 131 non-null    object
#  36  UPDRS III motor scale: specific items.22                 131 non-null    object
#  37  UPDRS III motor scale: specific items.23                 131 non-null    object
#  38  UPDRS III motor scale: specific items.24                 131 non-null    object
#  39  UPDRS III motor scale: specific items.25                 131 non-null    object
#  40  UPDRS III motor scale: specific items.26                 131 non-null    object
#  41  Speech examination: speaking task of reading passage     131 non-null    object
#  42  Speech examination: speaking task of reading passage.1   131 non-null    object
#  43  Speech examination: speaking task of reading passage.2   131 non-null    object
#  44  Speech examination: speaking task of reading passage.3   131 non-null    object
#  45  Speech examination: speaking task of reading passage.4   131 non-null    object
#  46  Speech examination: speaking task of reading passage.5   131 non-null    object
#  47  Speech examination: speaking task of reading passage.6   131 non-null    object
#  48  Speech examination: speaking task of reading passage.7   131 non-null    object
#  49  Speech examination: speaking task of reading passage.8   131 non-null    object
#  50  Speech examination: speaking task of reading passage.9   131 non-null    object
#  51  Speech examination: speaking task of reading passage.10  131 non-null    object
#  52  Speech examination: speaking task of reading passage.11  131 non-null    object
#  53  Speech examination: speaking task of monologue           131 non-null    object
#  54  Speech examination: speaking task of monologue.1         131 non-null    object
#  55  Speech examination: speaking task of monologue.2         131 non-null    object
#  56  Speech examination: speaking task of monologue.3         131 non-null    object
#  57  Speech examination: speaking task of monologue.4         131 non-null    object
#  58  Speech examination: speaking task of monologue.5         131 non-null    object
#  59  Speech examination: speaking task of monologue.6         131 non-null    object
#  60  Speech examination: speaking task of monologue.7         131 non-null    object
#  61  Speech examination: speaking task of monologue.8         131 non-null    object
#  62  Speech examination: speaking task of monologue.9         131 non-null    object
#  63  Speech examination: speaking task of monologue.10        131 non-null    object
#  64  Speech examination: speaking task of monologue.11        131 non-null    object
# dtypes: object(65)
# memory usage: 66.7+ KB

# %%
# Combine the first row with the header

def create_combined_header(df_parkinsons):
    new_header = [str(i) + ' ' + str(j) for i, j in zip(df_parkinsons.columns, df_parkinsons.iloc[0])]
    df_parkinsons.columns = new_header
    df_parkinsons = df_parkinsons.drop(df_parkinsons.index[0])
    df_parkinsons.reset_index(drop=True, inplace=True)
    
    return df_parkinsons

df_parkinsons = create_combined_header(df_parkinsons)

# %%
df_parkinsons.head()
# Out:
#   Unnamed: 0 Participant code Demographic information Age (years)  \
# 0                        PD01                                  58
# 1                        PD02                                  68
# 2                        PD03                                  68
# 3                        PD04                                  75
# 4                        PD05                                  61
#
#   Demographic information.1 Gender  \
# 0                                F
# 1                                F
# 2                                M
# 3                                M
# 4                                M
#
#   Clinical information Positive history of Parkinson disease in family  \
# 0                                                 No
# 1                                                 No
# 2                                                 No
# 3                                                 No
# 4                                                Yes
#
#   Clinical information.1 Age of disease onset (years)  \
# 0                                                 56
# 1                                                 67
# 2                                                 67
# 3                                                 73
# 4                                                 60
#
#   Clinical information.2 Duration of disease from first symptoms (years)  \
# 0                                                  2
# 1                                                  1
# 2                                                  1
# 3                                                  2
# 4                                                0.7
#
#   Medication Antidepressant therapy Medication.1 Antiparkinsonian medication  \
# 0                                No                                       No
# 1                                No                                       No
# 2                                No                                       No
# 3                                No                                       No
# 4                                No                                       No
#
#   Medication.2 Antipsychotic medication  \
# 0                                    No
# 1                                    No
# 2                                    No
# 3                                    No
# 4                                    No
#
#   Medication.3 Benzodiazepine medication  ...  \
# 0                                     No  ...
# 1                                     No  ...
# 2                                     No  ...
# 3                                     No  ...
# 4                                     No  ...
#
#   Speech examination: speaking task of monologue.2 Acceleration of speech timing (-/min2)  \
# 0                                              -2.82
# 1                                                8.2
# 2                                               4.71
# 3                                              -9.09
# 4                                              11.77
#
#   Speech examination: speaking task of monologue.3 Duration of pause intervals (ms)  \
# 0                                                158
# 1                                                295
# 2                                                280
# 3                                                397
# 4                                                206
#
#   Speech examination: speaking task of monologue.4 Duration of voiced intervals (ms)  \
# 0                                                318
# 1                                                264
# 2                                                317
# 3                                                800
# 4                                                480
#
#   Speech examination: speaking task of monologue.5 Gaping                         in-between voiced\nintervals                   (-/min)  \
# 0                                              49.01
# 1                                              40.56
# 2                                              48.97
# 3                                              18.69
# 4                                              33.54
#
#   Speech examination: speaking task of monologue.6 Duration of unvoiced stops (ms)  \
# 0                                              22.37
# 1                                              26.88
# 2                                              22.37
# 3                                              49.37
# 4                                              26.87
#
#   Speech examination: speaking task of monologue.7 Decay of unvoiced fricatives              (?/min)  \
# 0                                              0.588
# 1                                             -0.825
# 2                                             -0.955
# 3                                              0.791
# 4                                              0.075
#
#   Speech examination: speaking task of monologue.8 Relative loudness of respiration (dB)  \
# 0                                             -19.77
# 1                                             -23.26
# 2                                             -13.29
# 3                                             -25.08
# 4                                             -22.32
#
#   Speech examination: speaking task of monologue.9 Pause intervals per respiration (-)  \
# 0                                                  6
# 1                                                  4
# 2                                                  4
# 3                                                  2
# 4                                                  5
#
#   Speech examination: speaking task of monologue.10 Rate of speech respiration           (- /min)  \
# 0                                              13.81
# 1                                              21.77
# 2                                              22.52
# 3                                              14.37
# 4                                              14.61
#
#   Speech examination: speaking task of monologue.11 Latency of\nrespiratory exchange (ms)
# 0                                                127
# 1                                                313
# 2                                                201
# 3                                                151
# 4                                                151
#
# [5 rows x 65 columns]

# %%
df_parkinsons.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130 entries, 0 to 129
# Data columns (total 65 columns):
#  #   Column                                                                                                                                 Non-Null Count  Dtype
# ---  ------                                                                                                                                 --------------  -----
#  0   Unnamed: 0 Participant code                                                                                                            130 non-null    object
#  1   Demographic information Age (years)                                                                                                    130 non-null    object
#  2   Demographic information.1 Gender                                                                                                       130 non-null    object
#  3   Clinical information Positive history of Parkinson disease in family                                                                   130 non-null    object
#  4   Clinical information.1 Age of disease onset (years)                                                                                    130 non-null    object
#  5   Clinical information.2 Duration of disease from first symptoms (years)                                                                 130 non-null    object
#  6   Medication Antidepressant therapy                                                                                                      130 non-null    object
#  7   Medication.1 Antiparkinsonian medication                                                                                               130 non-null    object
#  8   Medication.2 Antipsychotic medication                                                                                                  130 non-null    object
#  9   Medication.3 Benzodiazepine medication                                                                                                 130 non-null    object
#  10  Medication.4 Levodopa equivalent (mg/day)                                                                                              130 non-null    object
#  11  Medication.5 Clonazepam (mg/day)                                                                                                       130 non-null    object
#  12  Overview of motor examination Hoehn & Yahr scale (-)                                                                                   130 non-null    object
#  13  Overview of motor examination.1 UPDRS III total (-)                                                                                    130 non-null    object
#  14  UPDRS III motor scale: specific items 18. Speech                                                                                       130 non-null    object
#  15  UPDRS III motor scale: specific items.1 19. Facial Expression                                                                          130 non-null    object
#  16  UPDRS III motor scale: specific items.2 20. Tremor at Rest - head                                                                      130 non-null    object
#  17  UPDRS III motor scale: specific items.3 20. Tremor at Rest - RUE                                                                       130 non-null    object
#  18  UPDRS III motor scale: specific items.4 20. Tremor at Rest - LUE                                                                       130 non-null    object
#  19  UPDRS III motor scale: specific items.5 20. Tremor at Rest - RLE                                                                       130 non-null    object
#  20  UPDRS III motor scale: specific items.6 20. Tremor at Rest - LLE                                                                       130 non-null    object
#  21  UPDRS III motor scale: specific items.7 21. Action or Postural Tremor - RUE                                                            130 non-null    object
#  22  UPDRS III motor scale: specific items.8 21. Action or Postural Tremor - LUE                                                            130 non-null    object
#  23  UPDRS III motor scale: specific items.9 22. Rigidity - neck                                                                            130 non-null    object
#  24  UPDRS III motor scale: specific items.10 22. Rigidity - RUE                                                                            130 non-null    object
#  25  UPDRS III motor scale: specific items.11 22. Rigidity - LUE                                                                            130 non-null    object
#  26  UPDRS III motor scale: specific items.12 22. Rigidity - RLE                                                                            130 non-null    object
#  27  UPDRS III motor scale: specific items.13 22. Rigidity - LLE                                                                            130 non-null    object
#  28  UPDRS III motor scale: specific items.14 23.Finger Taps - RUE                                                                          130 non-null    object
#  29  UPDRS III motor scale: specific items.15 23.Finger Taps - LUE                                                                          130 non-null    object
#  30  UPDRS III motor scale: specific items.16 24. Hand Movements  - RUE                                                                     130 non-null    object
#  31  UPDRS III motor scale: specific items.17 24. Hand Movements  - LUE                                                                     130 non-null    object
#  32  UPDRS III motor scale: specific items.18 25. Rapid Alternating Movements - RUE                                                         130 non-null    object
#  33  UPDRS III motor scale: specific items.19 25. Rapid Alternating Movements -  LUE                                                        130 non-null    object
#  34  UPDRS III motor scale: specific items.20 26. Leg Agility - RLE                                                                         130 non-null    object
#  35  UPDRS III motor scale: specific items.21 26. Leg Agility - LLE                                                                         130 non-null    object
#  36  UPDRS III motor scale: specific items.22 27.  Arising from Chair                                                                       130 non-null    object
#  37  UPDRS III motor scale: specific items.23 28. Posture                                                                                   130 non-null    object
#  38  UPDRS III motor scale: specific items.24 29. Gait                                                                                      130 non-null    object
#  39  UPDRS III motor scale: specific items.25 30. Postural Stability                                                                        130 non-null    object
#  40  UPDRS III motor scale: specific items.26 31. Body Bradykinesia and Hypokinesia                                                         130 non-null    object
#  41  Speech examination: speaking task of reading passage Entropy of speech timing (-)                                                      130 non-null    object
#  42  Speech examination: speaking task of reading passage.1 Rate of speech timing (-/min)                                                   130 non-null    object
#  43  Speech examination: speaking task of reading passage.2 Acceleration of speech timing                                (-/min2)           130 non-null    object
#  44  Speech examination: speaking task of reading passage.3 Duration of pause intervals (ms)                                                130 non-null    object
#  45  Speech examination: speaking task of reading passage.4 Duration of voiced intervals (ms)                                               130 non-null    object
#  46  Speech examination: speaking task of reading passage.5 Gaping                          in-between voiced
# intervals  (-/min)            130 non-null    object
#  47  Speech examination: speaking task of reading passage.6 Duration of unvoiced stops (ms)                                                 130 non-null    object
#  48  Speech examination: speaking task of reading passage.7 Decay of unvoiced fricatives              (promile/min)                         130 non-null    object
#  49  Speech examination: speaking task of reading passage.8 Relative loudness of respiration (dB)                                           130 non-null    object
#  50  Speech examination: speaking task of reading passage.9 Pause intervals per respiration (-)                                             130 non-null    object
#  51  Speech examination: speaking task of reading passage.10 Rate of speech respiration                (-/min)                              130 non-null    object
#  52  Speech examination: speaking task of reading passage.11 Latency of
# respiratory exchange (ms)                                           130 non-null    object
#  53  Speech examination: speaking task of monologue Entropy of speech timing (-)                                                            130 non-null    object
#  54  Speech examination: speaking task of monologue.1 Rate of speech timing (-/min)                                                         130 non-null    object
#  55  Speech examination: speaking task of monologue.2 Acceleration of speech timing (-/min2)                                                130 non-null    object
#  56  Speech examination: speaking task of monologue.3 Duration of pause intervals (ms)                                                      130 non-null    object
#  57  Speech examination: speaking task of monologue.4 Duration of voiced intervals (ms)                                                     130 non-null    object
#  58  Speech examination: speaking task of monologue.5 Gaping                         in-between voiced
# intervals                   (-/min)  130 non-null    object
#  59  Speech examination: speaking task of monologue.6 Duration of unvoiced stops (ms)                                                       130 non-null    object
#  60  Speech examination: speaking task of monologue.7 Decay of unvoiced fricatives              (?/min)                                     130 non-null    object
#  61  Speech examination: speaking task of monologue.8 Relative loudness of respiration (dB)                                                 130 non-null    object
#  62  Speech examination: speaking task of monologue.9 Pause intervals per respiration (-)                                                   130 non-null    object
#  63  Speech examination: speaking task of monologue.10 Rate of speech respiration           (- /min)                                        130 non-null    object
#  64  Speech examination: speaking task of monologue.11 Latency of
# respiratory exchange (ms)                                                 130 non-null    object
# dtypes: object(65)
# memory usage: 66.1+ KB

# %%
# Remove extra spaces from column names

def clean_column_names(df_parkinsons):
    df_parkinsons.columns = df_parkinsons.columns.str.replace(r'\s+', ' ', regex=True).str.strip()
    return df_parkinsons

# %%
# Convert columns of interest to numeric values so that I can analze and plot them

def clean_and_convert_to_numeric(df_parkinsons, columns_to_convert):
    df_parkinsons = clean_column_names(df_parkinsons)

    for col in columns_to_convert:
        df_parkinsons[col] = pd.to_numeric(df_parkinsons[col].astype(str).str.replace(r'[^\d.]+', '', regex=True), errors='coerce')
    return df_parkinsons

columns_to_convert = ['Demographic information Age (years)', 'Clinical information.1 Age of disease onset (years)', 
                      'Clinical information.2 Duration of disease from first symptoms (years)', 
                      'Speech examination: speaking task of reading passage.3 Duration of pause intervals (ms)', 
                      'Speech examination: speaking task of reading passage.5 Gaping in-between voiced intervals (-/min)', 
                      'Speech examination: speaking task of reading passage.11 Latency of respiratory exchange (ms)', 
                      'Speech examination: speaking task of reading passage.9 Pause intervals per respiration (-)', 
                      'Speech examination: speaking task of monologue.3 Duration of pause intervals (ms)', 
                      'Speech examination: speaking task of monologue.5 Gaping in-between voiced intervals (-/min)', 
                      'Speech examination: speaking task of monologue.9 Pause intervals per respiration (-)', 
                      'Speech examination: speaking task of monologue.11 Latency of respiratory exchange (ms)'] 

df_parkinsons = clean_and_convert_to_numeric(df_parkinsons, columns_to_convert)

# %% [markdown]
# Duration of Pause Intervals (ms): This measures the actual length of the pauses during speech.
#
# Gaping in-between Voiced Intervals (-/min): This indicates the frequency of pauses which can be important for the duration measurement.
#
# Pause Intervals per Respiration (-): Measures how often pauses occur in the context of the breathing cycle, which could be related to speech initiation difficulties.
#
# Latency of Respiratory Exchange (ms): Not exactly about speech pauses but could be related to the control of speech initiation and pauses.

# %%
df_parkinsons.describe()
# Out:
#        Demographic information Age (years)  \
# count                           130.000000
# mean                             64.330769
# std                              10.133518
# min                              34.000000
# 25%                              58.250000
# 50%                              66.500000
# 75%                              72.000000
# max                              83.000000
#
#        Clinical information.1 Age of disease onset (years)  \
# count                                          80.000000
# mean                                           60.750000
# std                                            10.726166
# min                                            30.000000
# 25%                                            56.000000
# 50%                                            62.500000
# 75%                                            68.250000
# max                                            81.000000
#
#        Clinical information.2 Duration of disease from first symptoms (years)  \
# count                                          80.000000
# mean                                            4.212500
# std                                             4.059163
# min                                             0.500000
# 25%                                             1.000000
# 50%                                             2.750000
# 75%                                             5.000000
# max                                            17.000000
#
#        Speech examination: speaking task of reading passage.3 Duration of pause intervals (ms)  \
# count                                         130.000000
# mean                                          166.646154
# std                                            46.487618
# min                                            96.000000
# 25%                                           138.250000
# 50%                                           156.000000
# 75%                                           185.000000
# max                                           388.000000
#
#        Speech examination: speaking task of reading passage.5 Gaping in-between voiced intervals (-/min)  \
# count                                         130.000000
# mean                                           53.262846
# std                                            15.606155
# min                                            13.720000
# 25%                                            42.712500
# 50%                                            52.675000
# 75%                                            62.945000
# max                                           109.500000
#
#        Speech examination: speaking task of reading passage.9 Pause intervals per respiration (-)  \
# count                                         130.000000
# mean                                            5.571154
# std                                             2.417282
# min                                             1.000000
# 25%                                             4.000000
# 50%                                             5.250000
# 75%                                             6.500000
# max                                            18.500000
#
#        Speech examination: speaking task of reading passage.11 Latency of respiratory exchange (ms)  \
# count                                         130.000000
# mean                                          134.630769
# std                                            63.367164
# min                                            10.000000
# 25%                                            89.000000
# 50%                                           124.500000
# 75%                                           167.000000
# max                                           441.000000
#
#        Speech examination: speaking task of monologue.3 Duration of pause intervals (ms)  \
# count                                         130.000000
# mean                                          229.069231
# std                                            79.696828
# min                                           117.000000
# 25%                                           177.000000
# 50%                                           212.500000
# 75%                                           263.250000
# max                                           611.000000
#
#        Speech examination: speaking task of monologue.5 Gaping in-between voiced intervals (-/min)  \
# count                                         130.000000
# mean                                           45.089692
# std                                            12.522043
# min                                            14.680000
# 25%                                            36.987500
# 50%                                            44.420000
# 75%                                            53.532500
# max                                            74.160000
#
#        Speech examination: speaking task of monologue.9 Pause intervals per respiration (-)  \
# count                                         130.000000
# mean                                            4.457692
# std                                             1.791490
# min                                             1.500000
# 25%                                             3.000000
# 50%                                             4.000000
# 75%                                             5.000000
# max                                            13.500000
#
#        Speech examination: speaking task of monologue.11 Latency of respiratory exchange (ms)
# count                                          130.00000
# mean                                           145.20000
# std                                             85.20749
# min                                             15.00000
# 25%                                             90.50000
# 50%                                            127.50000
# 75%                                            176.25000
# max                                            593.00000

# %%
# Compare mean for the duration of pause intervals for each group (PD, RBD, HC)

df_parkinsons['Group'] = df_parkinsons['Unnamed: 0 Participant code'].str.extract(r'(\D+)')
mean_pause_durations_reading = df_parkinsons.groupby('Group')['Speech examination: speaking task of reading passage.3 Duration of pause intervals (ms)'].mean()

mean_pause_durations_reading
# Out:
# Group
# HC     149.820000
# PD     186.066667
# RBD    171.820000
# Name: Speech examination: speaking task of reading passage.3 Duration of pause intervals (ms), dtype: float64

# %%
df_parkinsons['Group'] = df_parkinsons['Unnamed: 0 Participant code'].str.extract(r'(\D+)')
mean_pause_durations_monologue = df_parkinsons.groupby('Group')['Speech examination: speaking task of monologue.3 Duration of pause intervals (ms)'].mean()

mean_pause_durations_monologue
# Out:
# Group
# HC     198.36
# PD     264.90
# RBD    238.28
# Name: Speech examination: speaking task of monologue.3 Duration of pause intervals (ms), dtype: float64

# %%
df_parkinsons2 = df_parkinsons.rename(columns={
    'Speech examination: speaking task of monologue.3 Duration of pause intervals (ms)': 'Monologue: Pause',
    'Speech examination: speaking task of reading passage.3 Duration of pause intervals (ms)': 'Reading: Pause',
    'Demographic information Age (years)': 'Age', 
    'Clinical information.1 Age of disease onset (years)': 'Age Onset', 
    'Clinical information.2 Duration of disease from first symptoms (years)': 'Duration of disease from 1st symptoms',   
    'Speech examination: speaking task of reading passage.5 Gaping in-between voiced intervals (-/min)': 'Reading:Gaping', 
    'Speech examination: speaking task of reading passage.11 Latency of respiratory exchange (ms)': 'Reading: Latency',   
    'Speech examination: speaking task of monologue.5 Gaping in-between voiced intervals (-/min)': 'Monologue: Gaping', 
    'Speech examination: speaking task of monologue.9 Pause intervals per respiration (-)': 'Monologue: Pause/Respiration', 
    'Speech examination: speaking task of monologue.11 Latency of respiratory exchange (ms)': 'Latency of respiratory exchange'
})
